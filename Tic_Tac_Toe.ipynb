# %%
#TicTacToe
#Requirements:2 players should be able to play the game (both sitting at the same computer). 
            #The board should be printed out every time a player makes a move. 
            #You should be able to accept input of the player position and then place a symbol on the board

#Clear output
from IPython.display import clear_output

#Display board/available positions

#Have player enter letter and position

#Update selected position and display board

#Do you want keep playing?
